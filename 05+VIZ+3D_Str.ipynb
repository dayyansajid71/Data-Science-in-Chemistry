# %% [markdown]
# <p style="color:#824AE8;font-family:Ubuntu Light;font-size:140%">DATA SCIENCE IN CHEMISTRY</p>

# %% [markdown]
# # Visualizing 3D Structures

# %%
pip install imolecule
# Out:
# ...
#   Using cached imolecule-0.2.2-py2.py3-none-any.whl.metadata (976 bytes)
# ...
# Using cached imolecule-0.2.2-py2.py3-none-any.whl (475 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import imolecule

# %%
imolecule.draw("CCO", size=(400, 400), drawing_type = "wireframe", show_save = True)
# Out:
# <div id="molecule_e2a73e37-a543-47bd-a278-c64a1b19d6c9"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {
#                            jquery: 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.0/jquery.min',
#                            imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_e2a73e37-a543-47bd-a278-c64a1b19d6c9');
#                $d.width(400); $d.height(400);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'wireframe',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: true});
#                $d.imolecule.addElements({});
# ...

# %%
imolecule.draw("InChI=1S/C4H5OS/c1-3-6-4-2-5-1/h1,3-4H,2H2", "inchi")
# Out:
# <div id="molecule_22d2ca07-f67e-479d-8a4a-891f19d26646"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {
#                            jquery: 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.0/jquery.min',
#                            imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_22d2ca07-f67e-479d-8a4a-891f19d26646');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
# ...

# %%
imolecule.draw(r"E:\IN SILICO CHEMISTRY\Notebooks\IN SILICO MOFS\NU1000.cif")
# Out:
# <div id="molecule_05a2006c-0e52-4123-8c52-c5ef2ce8ef6f"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {
#                            jquery: 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.0/jquery.min',
#                            imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_05a2006c-0e52-4123-8c52-c5ef2ce8ef6f');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
# ...
